# %% [markdown]
# <a href="https://colab.research.google.com/github/harishwork-s/aimlexercisesincollab/blob/main/logistics_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
y_predicted = model.predict(X_test)
model.predict_proba(X_test)
# Out:
# array([[0.25647992, 0.74352008],
#        [0.89800029, 0.10199971],
#        [0.93326706, 0.06673294],
#        [0.35398844, 0.64601156],
#        [0.88297779, 0.11702221],
#        [0.9762895 , 0.0237105 ]])

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8) #0.8 means 80%
X_test
# Out:
#     age
# 14   49
# 11   28
# 16   25
# 4    46
# 13   29
# 19   18

# %%
plt.plot(df.age,df.bought_insurance,marker='*',color='green')
#plt.plot or plt.scatter

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
